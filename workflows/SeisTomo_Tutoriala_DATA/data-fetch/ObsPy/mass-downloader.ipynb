# %% [markdown]
# # [Mass Downloader for FDSN Compliant Web Services](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.html)
#
# It requires the following three separate things:
#
# 1. [Data Selection](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.html#step-1-data-selection): The data to be downloaded can be defined by enforcing geographical or temporal constraints and a couple of other options.
# 2. [Storage Options](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.html#step-2-storage-options): Choosing where the final MiniSEED and StationXML files should be stored.
# 3. [Start the Download](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.html#step-3-start-the-download): Choose from which provider(s) to download and then launch the downloading process.

# %% [markdown]
# ## [M5.9 Earthquake in Myanmar](https://earthquake.usgs.gov/earthquakes/eventpage/us70008xhp/executive)
#
#
# - `2020-04-16 11:45:23` | `22.800N` | `94.029E` | `10.0 km ` | `5.9 mww`

# %%
import os
from obspy import UTCDateTime
from obspy.clients.fdsn.mass_downloader import RectangularDomain, Restrictions, MassDownloader

# %% [markdown]
# ## Step 1: Data Selection
#
# Data set selection serves the purpose to limit the data to be downloaded to data useful for the purpose at hand.
#
# It is handled by two objects:
# - subclasses of [Domain object](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.domain.html)
# - [Restrictions class](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.restrictions.Restrictions.html)

# %% [markdown]
# ## Domain
#
# - [RectangularDomain](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.domain.RectangularDomain.html): A rectangular domain defined by latitude and longitude bounds
# - [CircularDomain](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.domain.CircularDomain.html): A circular domain defined by a center point and minimum and maximum radius from that point in degrees
# - [GlobalDomain](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.domain.GlobalDomain.html): Domain spanning the whole globe
# - [Domain](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.domain.Domain.html): Abstract base class defining a domain - subclass it to define a new domain

# %%
# Rectangular Domain
domain = RectangularDomain(minlatitude=16, maxlatitude=27,
                           minlongitude=90, maxlongitude=100)

# %% [markdown]
# ## Restrictions
#
# Non-domain restrictions for a query

# %%
# event origin time
event_otime = "2020-04-16T11:45:23.000Z"
origin_time = UTCDateTime(event_otime)
event_fname = "".join(event_otime.split("T")[0].split("-")) + "".join("".join("".join(event_otime.split("T")[1].split("Z")).split(".")).split(":"))

print("orign time for output file: {}".format(event_fname))
# Out:
# orign time for output file: 20200416114523000

# %%
# Restrictions
restrictions = Restrictions(
    # time range
    starttime=origin_time - 2 * 60,
    endtime=origin_time + 10* 60,
    
    # station start and end time (default values used)
    station_starttime=None,
    station_endtime=None,
    
    # The length of one chunk in seconds (default value used)
    chunklength_in_sec=None,
    
    # network and station (default values used)
    network=None,
    station=None,
    location=None,
    channel=None,
    exclude_networks=(),
    exclude_stations=(),
    limit_stations_to_inventory=None,
    
    # If True, miniSEED files with gaps and/or overlaps will be rejected (default is True)
    reject_channels_with_gaps=False,
    
    # The minimum length of the data as a fraction of the requested time frame (0.0~1.0, default is 0.9)
    minimum_length=0.0,
    
    # Each MiniSEED file also has an associated StationXML file,
    # otherwise the MiniSEED files will be deleted afterwards (default is True)
    sanitize=False,
    
    # The minimum inter-station distance (default is 1000)
    minimum_interstation_distance_in_m=0,
    
    # Priority list for the channels.
    # Will not be used if the channel argument is used.
    channel_priorities=('BH[ZNE12]', 'BL[ZNE12]',
                        'HH[ZNE12]', 'HL[ZNE12]',
                        'SH[ZNE12]', 'SL[ZNE12]',
                        'EH[ZNE12]', 'EL[ZNE12]',
                        'SP[ZNE12]', 'EP[ZNE12]', 
                        'DP[ZNE12]'),

    # Priority list for the locations.
    # Will not be used if the location argument is used. (defaults are used)
    location_priorities=('', '00', '10', '01', '20', '02', '30', '03', '40', '04',
                         '50', '05', '60', '06', '70', '07', '80', '08', '90', '09'))

# %% [markdown]
# ## Step 2: Storage Options
#
# After determining what to download, the helpers must know where to store the requested data.
#
# - [Storing MiniSEED waveforms](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.html#storing-miniseed-waveforms)
# - [Storing StationXML files](https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.mass_downloader.html#storing-stationxml-files)

# %% [markdown]
# ## Storing options of MiniSEED waveforms

# %%
# Option 1: Folder Name
# This will cause all MiniSEED files to be stored as some_folder/NETWORK.STATION.LOCATION.CHANNEL__STARTTIME__ENDTIME.mseed.
# An example of this is waveforms-op1/BW.FURT..BHZ__20141027T163723Z__20141027T163733Z.mseed.
#mseed_storage = "waveforms-op1"


# Option 2: String Template
# An example of this is some_folder/BW/FURT/BHZ..20141027T163723Z.20141027T163733Z.mseed.
#mseed_storage = ("wavefroms-op2/{network}/{station}/{channel}.{location}.{starttime}.{endtime}.mseed")


# Option 3: Custom Function
# we need to write our own is_in_db function
def get_mseed_storage(network, station, location, channel, starttime,
                      endtime):
    # Returning True means that neither the data nor the StationXML file will be downloaded.
    #if is_in_db(network, station, location, channel, starttime, endtime):
    #    return True
    # If a string is returned the file will be saved in that location.
    return os.path.join("waveforms-op3/{}".format(event_fname), "{}.{}.{}.{}.mseed".format(network, station,location, channel))

mseed_storage = get_mseed_storage

# %% [markdown]
# ## Storing options of StationXML files

# %%
# Option 1: Folder Name
# This example will save the files to "stations-op1/NETWORK.STATION.xml", e.g. to "stations/BW.FURT.xml".
stationxml_storage = "stations-op1"


# Option 2: String Template
# This example will write to "some_folder/NETWORK/STATION.xml", in this case for example to "some_folder/BW/FURT.xml".
#stationxml_storage = "station-op2/{network}/{station}.xml"


# Option 3: Custom Function
# we need to write our own is_in_db function
#def get_stationxml_storage(network, station, channels, starttime, endtime):
#    available_channels = []
#    missing_channels = []
#    for location, channel in channels:
#        if is_in_db(network, station, location, channel, starttime, endtime):
#            available_channels.append((location, channel))
#        else:
#            missing_channels.append((location, channel))
#    filename = os.path.join("stations-op3", "{}.{}.xml".format(network, station))
#    return {
#        "available_channels": available_channels,
#        "missing_channels": missing_channels,
#        "filename": filename}
#
#stationxml_storage = get_stationxml_storage

# %% [markdown]
# ## Step 3: Start the Download
#
# The final step is to actually start the download. Pass the previously created domain, restrictions, and path settings and off you go.

# %%
# List of FDSN client names or service URLS
# Will use all FDSN implementations known to ObsPy except RASPISHAKE if set to None
# The order in the list also determines their priority
# To include RASPISHAKE, you must set this parameter to obspy.clients.fdsn.header.URL_MAPPINGS explicitly
#mdl = MassDownloader(providers=["IRIS", "GFZ", "SCEDC"])
mdl = MassDownloader()

# domain, restrictions, mseed_storage, stationxml_storage,
# download_chunk_size_in_mb=20, threads_per_client=3, print_report=True (default)
tt = mdl.download(domain, restrictions, threads_per_client=3, 
                  mseed_storage=mseed_storage, stationxml_storage=stationxml_storage)
# Out:
# [2020-12-13 23:58:37,509] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for BGR, EMSC, ETH, GEONET, GFZ, ICGC, INGV, IPGP, ISC, KNMI, KOERI, LMU, NCEDC, NIEP, NOA, RESIF, SCEDC, TEXNET, UIB-NORSAR, USGS, USP, ORFEUS, IRIS.
# [2020-12-13 23:58:38,175] - obspy.clients.fdsn.mass_downloader - INFO: Cannot use client 'ISC' as it does not have 'dataselect' and/or 'station' services.
# [2020-12-13 23:58:38,905] - obspy.clients.fdsn.mass_downloader - INFO: Cannot use client 'EMSC' as it does not have 'dataselect' and/or 'station' services.
# [2020-12-13 23:58:38,981] - obspy.clients.fdsn.mass_downloader - INFO: Cannot use client 'USGS' as it does not have 'dataselect' and/or 'station' services.
# [2020-12-13 23:58:40,384] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 20 client(s): BGR, ETH, GEONET, GFZ, ICGC, INGV, IPGP, KNMI, KOERI, LMU, NCEDC, NIEP, NOA, RESIF, SCEDC, TEXNET, UIB-NORSAR, USP, ORFEUS, IRIS.
# [2020-12-13 23:58:40,387] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-12-13 23:58:40,388] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - Requesting unreliable availability.
# [2020-12-13 23:58:40,779] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - No data available for request.
# [2020-12-13 23:58:40,780] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - No data available.
# [2020-12-13 23:58:40,781] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-12-13 23:58:40,782] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - Requesting unreliable availability.
# [2020-12-13 23:58:41,172] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - No data available for request.
# [2020-12-13 23:58:41,173] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - No data available.
# [2020-12-13 23:58:41,174] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-12-13 23:58:41,175] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - Requesting unreliable availability.
# [2020-12-13 23:58:41,288] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - No data available for request.
# [2020-12-13 23:58:41,289] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - No data available.
# [2020-12-13 23:58:41,290] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-12-13 23:58:41,291] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Requesting unreliable availability.
# [2020-12-13 23:58:41,851] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Successfully requested availability (0.56 seconds)
# [2020-12-13 23:58:41,859] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Found 29 stations (87 channels).
# [2020-12-13 23:58:41,860] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Will attempt to download data from 29 stations.
# [2020-12-13 23:58:41,863] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Status for 87 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-12-13 23:58:42,368] - obspy.clients.fdsn.mass_downloader - ERROR: Client 'GFZ' - Authentication failed.
# Detailed response of server:
#
# mK0@sD
# @}ii)ooWNs)H+DpjE3+i!9?QQZ(e^Iq6=S)
# Xmuclcptm
# X
# [2020-12-13 23:58:42,879] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Successfully downloaded 3 channels (of 37)
# [2020-12-13 23:58:42,881] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Launching basic QC checks...
# [2020-12-13 23:58:42,898] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Downloaded 0.1 MB [87.58 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-12-13 23:58:42,899] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Status for 84 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-12-13 23:58:42,900] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Status for 3 time intervals/channels after downloading: DOWNLOADED
# [2020-12-13 23:58:43,628] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Successfully downloaded 'stations-op1/GE.NPW.xml'.
# [2020-12-13 23:58:43,638] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Downloaded 1 station files [0.3 MB] in 0.7 seconds [388.05 KB/sec].
# [2020-12-13 23:58:43,640] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:43,640] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - Requesting unreliable availability.
# [2020-12-13 23:58:44,081] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - No data available for request.
# [2020-12-13 23:58:44,082] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - No data available.
# [2020-12-13 23:58:44,083] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:44,084] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - Requesting unreliable availability.
# [2020-12-13 23:58:44,574] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - No data available for request.
# [2020-12-13 23:58:44,575] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - No data available.
# [2020-12-13 23:58:44,576] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:44,577] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Requesting unreliable availability.
# [2020-12-13 23:58:44,948] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - No data available for request.
# [2020-12-13 23:58:44,950] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - No data available.
# [2020-12-13 23:58:44,951] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:44,951] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - Requesting unreliable availability.
# [2020-12-13 23:58:45,321] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - No data available for request.
# [2020-12-13 23:58:45,322] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - No data available.
# [2020-12-13 23:58:45,322] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:45,323] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - Requesting unreliable availability.
# [2020-12-13 23:58:45,791] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - No data available for request.
# [2020-12-13 23:58:45,792] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - No data available.
# [2020-12-13 23:58:45,792] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:45,793] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - Requesting unreliable availability.
# [2020-12-13 23:58:46,195] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - No data available for request.
# [2020-12-13 23:58:46,196] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - No data available.
# [2020-12-13 23:58:46,197] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:46,198] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - Requesting unreliable availability.
# [2020-12-13 23:58:46,761] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - No data available for request.
# [2020-12-13 23:58:46,762] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - No data available.
# [2020-12-13 23:58:46,763] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:46,764] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - Requesting unreliable availability.
# [2020-12-13 23:58:47,192] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - No data available for request.
# [2020-12-13 23:58:47,194] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - No data available.
# [2020-12-13 23:58:47,195] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:47,195] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - Requesting unreliable availability.
# [2020-12-13 23:58:47,633] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - No data available for request.
# [2020-12-13 23:58:47,634] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - No data available.
# [2020-12-13 23:58:47,635] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:47,636] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - Requesting reliable availability.
# [2020-12-13 23:58:48,422] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - No data available for request.
# [2020-12-13 23:58:48,423] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - No data available.
# [2020-12-13 23:58:48,424] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:48,425] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - Requesting unreliable availability.
# [2020-12-13 23:58:49,634] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - No data available for request.
# [2020-12-13 23:58:49,635] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - No data available.
# [2020-12-13 23:58:49,636] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:49,637] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - Requesting reliable availability.
# [2020-12-13 23:58:50,245] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - No data available for request.
# [2020-12-13 23:58:50,246] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - No data available.
# [2020-12-13 23:58:50,247] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:50,248] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - Requesting unreliable availability.
# [2020-12-13 23:58:50,666] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - No data available for request.
# [2020-12-13 23:58:50,668] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - No data available.
# [2020-12-13 23:58:50,669] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:50,670] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Requesting unreliable availability.
# [2020-12-13 23:58:51,395] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Successfully requested availability (0.72 seconds)
# [2020-12-13 23:58:51,397] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Found 1 stations (3 channels).
# [2020-12-13 23:58:51,398] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Will attempt to download data from 1 stations.
# [2020-12-13 23:58:51,400] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Status for 3 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-12-13 23:58:52,111] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - No data available for request.
# [2020-12-13 23:58:52,114] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Launching basic QC checks...
# [2020-12-13 23:58:52,115] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-12-13 23:58:52,116] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Status for 3 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-12-13 23:58:52,119] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - No station information to download.
# [2020-12-13 23:58:52,121] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - No data could be downloaded.
# [2020-12-13 23:58:52,122] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:52,123] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - Requesting unreliable availability.
# [2020-12-13 23:58:52,495] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - No data available for request.
# [2020-12-13 23:58:52,496] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - No data available.
# [2020-12-13 23:58:52,498] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2020-12-13 23:58:52,499] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Requesting reliable availability.
# [2020-12-13 23:58:55,129] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully requested availability (2.63 seconds)
# [2020-12-13 23:58:55,158] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Found 12 stations (36 channels).
# [2020-12-13 23:58:55,159] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Will attempt to download data from 12 stations.
# [2020-12-13 23:58:55,162] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 36 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-12-13 23:59:52,180] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 33 channels (of 36)
# [2020-12-13 23:59:52,181] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Launching basic QC checks...
# [2020-12-13 23:59:52,218] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Downloaded 4.7 MB [83.63 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-12-13 23:59:52,219] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 3 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-12-13 23:59:52,219] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 33 time intervals/channels after downloading: DOWNLOADED
# [2020-12-13 23:59:53,170] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.HKA.xml'.
# [2020-12-13 23:59:53,173] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/IU.CHTO.xml'.
# [2020-12-13 23:59:53,184] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/IN.SHL.xml'.
# [2020-12-13 23:59:53,677] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.KTN.xml'.
# [2020-12-13 23:59:53,685] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.KTA.xml'.
# [2020-12-13 23:59:53,699] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.NGU.xml'.
# [2020-12-13 23:59:54,185] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.SIM.xml'.
# [2020-12-13 23:59:54,202] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.TMU.xml'.
# [2020-12-13 23:59:54,204] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.TGI.xml'.
# [2020-12-13 23:59:54,694] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/MM.YGN.xml'.
# [2020-12-13 23:59:54,720] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 'stations-op1/TM.MHIT.xml'.
# [2020-12-13 23:59:54,767] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Downloaded 11 station files [0.9 MB] in 2.5 seconds [373.51 KB/sec].
# [2020-12-13 23:59:54,769] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-12-13 23:59:54,769] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-12-13 23:59:54,770] - obspy.clients.fdsn.mass_downloader - INFO: 0 StationXML files [0.0 MB] already existed.
# [2020-12-13 23:59:54,771] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,772] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,773] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,774] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,775] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,776] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,777] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Acquired 3 MiniSEED files [0.1 MB].
# [2020-12-13 23:59:54,778] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Acquired 1 StationXML files [0.3 MB].
# [2020-12-13 23:59:54,779] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,779] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,780] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,781] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,782] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,782] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,783] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,784] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,784] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,785] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,786] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,786] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,787] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,787] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,788] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,788] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,789] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,789] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,790] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,790] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,791] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,793] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,794] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,794] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,795] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,795] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,796] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,797] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,797] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-12-13 23:59:54,798] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - Acquired 0 StationXML files [0.0 MB].
# [2020-12-13 23:59:54,799] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Acquired 33 MiniSEED files [4.7 MB].
# [2020-12-13 23:59:54,799] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Acquired 11 StationXML files [0.9 MB].
# [2020-12-13 23:59:54,800] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 5.9 MB in total.
